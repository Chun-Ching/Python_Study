# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([1,2,3,4,5])

# %%
plot([-1,-2,25,56,87,12])

# %%
randn()
# Out:
# -1.7323186068739065

# %%
randn(10)
# Out:
# array([ 0.43401258,  0.2750294 ,  0.4593708 ,  0.67260049,  1.56844294,
#         0.99759764, -0.02898591,  0.46392024, -0.39406472, -1.47715232])

# %%
plot(randa(100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-78325a97d7ef> in <module>
# ----> 1 plot(randa(100))
#
# NameError: name 'randa' is not defined

# %%
plot(randn(100))

# %%
plot([-2,5,26,12,87],[3,5,87,-12,5])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.03480012, 0.76483045, 0.49098095, 0.18104152, 0.93732314,
#        0.05818878, 0.0253376 , 0.17356238, 0.40154652, 0.22099442,
#        0.96281364, 0.42151877, 0.27034445, 0.83368245, 0.28081711,
#        0.5792489 , 0.3954264 , 0.68703333, 0.54033925, 0.85529871,
#        0.74801063, 0.72258594, 0.30936008, 0.69204187, 0.24346713,
#        0.14157451, 0.82795619, 0.77912278, 0.22252666, 0.39991823,
#        0.39412682, 0.63512879, 0.47033959, 0.64634809, 0.59942449,
#        0.45372191, 0.76074665, 0.10935698, 0.56947424, 0.10028717,
#        0.86107472, 0.31148714, 0.40969204, 0.1166567 , 0.57702772,
#        0.21821487, 0.9706528 , 0.6998506 , 0.086894  , 0.77634263])

# %%
plt.plot(y)

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x) + x)

# %%
plt.plot(x, np.sin(x) + x)
plt.plot(x, np.cos(x))

# %%
L = np.array([3,-2,5,9,-6])

# %%
L<0
# Out:
# array([False,  True, False, False,  True])

# %%
L[0]
# Out:
# 3

# %%
L[2:4]
# Out:
# array([5, 9])

# %%
L[L<0]
# Out:
# array([-2, -6])

# %%
x = np.linspace(-5,5,500)
y = np.sinc(x)

plt.plot(x,y)

# %%
plt.plot(x,y)
plt.plot(x[y>0],y[y>0], 'o')

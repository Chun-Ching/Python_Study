# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("AAPL", "yahoo", start="2017-9-1", end="2018-12-31")

# %%
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-08-31  164.520004  163.479996  163.639999  164.000000  26785100.0
# 2017-09-01  164.940002  163.630005  164.800003  164.050003  16591100.0
# 2017-09-05  164.250000  160.559998  163.750000  162.080002  29468500.0
# 2017-09-06  162.990005  160.520004  162.710007  161.910004  21651700.0
# 2017-09-07  162.240005  160.360001  162.089996  161.259995  21928500.0
#
#              Adj Close
# Date
# 2017-08-31  158.612350
# 2017-09-01  158.660706
# 2017-09-05  156.755432
# 2017-09-06  156.590988
# 2017-09-07  155.962341

# %%
P = df["Adj Close"]

# %%
P.head()
# Out:
# Date
# 2017-08-31    158.612350
# 2017-09-01    158.660706
# 2017-09-05    156.755432
# 2017-09-06    156.590988
# 2017-09-07    155.962341
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %% [markdown]
# # 報酬率

# %%
r = P.diff()/P

# %%
r[100:].plot()

# %% [markdown]
# # 移動平均

# %%
P.rolling(window=20).mean()
# Out:
# Date
# 2017-08-31           NaN
# 2017-09-01           NaN
# 2017-09-05           NaN
# 2017-09-06           NaN
# 2017-09-07           NaN
#                  ...
# 2018-12-24    166.582103
# 2018-12-26    165.722518
# 2018-12-27    164.831406
# 2018-12-28    163.614194
# 2018-12-31    162.539837
# Name: Adj Close, Length: 335, dtype: float64

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
